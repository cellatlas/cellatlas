# %% [markdown]
# <a href="https://colab.research.google.com/github/cellatlas/cellatlas/blob/main/examples/atac-10xatac/qc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://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@github.com/cellatlas/cellatlas.git > /dev/null

# !pip install --quiet git+https://github.com/pmelsted/voyagerpy
# Out:
# Cloning into 'cellatlas'...
# remote: Enumerating objects: 493, done.
# remote: Counting objects: 100% (238/238), done.
# remote: Compressing objects: 100% (194/194), done.
# remote: Total 493 (delta 151), reused 93 (delta 44), pack-reused 255
# Receiving objects: 100% (493/493), 638.33 MiB | 32.52 MiB/s, done.
# Resolving deltas: 100% (280/280), done.
# Updating files: 100% (105/105), done.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 kB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 53.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 88.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 76.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 96.1 MB/s eta 0:00:00
#   Building wheel for voyagerpy (pyproject.toml) ... done
#   Building wheel for esda (setup.py) ... done

# %%
# !pip install --quiet anndata

# %%
# !gunzip /content/cellatlas/examples/atac-10xatac/cellatlas_out/adata.h5ad.gz

# %%
import voyagerpy as vp
import anndata
from matplotlib import pyplot as plt
import numpy as np

plt.rcParams.update({
    'figure.dpi': 120, 
    'font.size':  20})
_ = plt.ion()
# %config InlineBackend.figure_format = 'retina'

# %%
adata = anndata.read_h5ad("/content/cellatlas/examples/atac-10xatac/cellatlas_out/adata.h5ad")

# %%
adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [1:10009-10467, 1:12549-12760, 1:20354-20502, 1:22517-22952, 1:23532-23763, 1:24019-24352, 1:28894-29603, 1:45034-45386, 1:93345-93704, 1:96444-96955, 1:103914-104564, 1:113974-114189, 1:116989-117169, 1:142410-142590, 1:143192-143413, 1:166914-167282, 1:180810-180990, 1:181474-181571, 1:181713-181962, 1:185180-185613, 1:190708-190886, 1:191224-191880, 1:192253-192465, 1:193089-193428, 1:193734-193904, 1:194116-194282, 1:196375-196652, 1:199593-200080, 1:200315-200500, 1:204404-204636, 1:262807-262972, 1:267907-268123, 1:268405-268625, 1:269331-269705, 1:271195-271524, 1:273139-273627, 1:274351-274884, 1:280671-281128, 1:281537-281762, 1:282188-282373, 1:291564-291734, 1:292120-292422, 1:357289-357789, 1:359896-360143, 1:376679-377267, 1:387404-387609, 1:398693-398938, 1:406529-406930, 1:410847-411295, 1:414372-414740, 1:446261-446478, 1:449635-449971, 1:478459-478628, 1:480415-480785, 1:528824-529048, 1:586150-586243, 1:588629-588811, 1:605470-605598, 1:606806-607007, 1:628571-628816, 1:629085-630079, 1:630228-630433, 1:630679-631368, 1:631752-632953, 1:633309-633551, 1:633717-634173, 1:634427-634921, 1:646453-646620, 1:649405-649583, 1:650729-650952, 1:666436-666633, 1:667373-667718, 1:684640-684734, 1:706609-706757, 1:734253-734401, 1:775141-775382, 1:776684-777292, 1:778052-779102, 1:779245-779428, 1:779629-780198, 1:788311-788490, 1:807316-807483, 1:816660-816966, 1:817072-817545, 1:817912-818107, 1:822928-823089, 1:826941-828008, 1:828885-829057, 1:839834-840250, 1:840480-840744, 1:840916-841103, 1:842640-842883, 1:843015-843181, 1:844046-844788, 1:854491-854920, 1:858045-858345, 1:869011-869213, 1:869632-870172, 1:876656-877007, 1:878718-878946, ...]
#
# [287981 rows x 0 columns]

# %%
adata.obs["sum"] = np.asarray(adata.X.sum(1)).reshape(-1)
adata.obs["detected"] = np.asarray((adata.X > 0).sum(1)).reshape(-1)

# %%
qc_features = ["sum", "detected"]

_ = vp.plt.plot_barcode_data(
    adata,
    y=qc_features,
    ncol=2,
)

# %%
_ = vp.plt.plot_barcodes_bin2d(adata, x='sum', y='detected', cmin=1)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 171 × 287981
#     obs: 'sum', 'detected'
